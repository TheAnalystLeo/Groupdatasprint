# %%
import pandas as pd
hdb = pd.read_csv('./datasets/hdb_streamlit.csv')

# %%
hdb.head()
# Out:
#    Unnamed: 0      id Tranc_YearMonth      town flat_type    street_name  \
# 0           0  122598      2012-07-01    BISHAN    5 ROOM   BISHAN ST 13
# 1           1   86070      2012-04-01    BISHAN    4 ROOM   BISHAN ST 22
# 2           2   26610      2013-01-01   GEYLANG    3 ROOM  ALJUNIED CRES
# 3           3  173300      2018-05-01   HOUGANG    5 ROOM  HOUGANG AVE 8
# 4           4  103385      2014-06-01  SENGKANG    5 ROOM  ANCHORVALE RD
#
#   storey_range  floor_area_sqm flat_model  resale_price  ...  \
# 0     07 TO 09             130   Improved      665000.0  ...
# 1     01 TO 05             103    Model A      550000.0  ...
# 2     07 TO 09              65   Improved      335000.0  ...
# 3     07 TO 09             120   Improved      433000.0  ...
# 4     10 TO 12             110   Improved      490000.0  ...
#
#    bus_stop_nearest_distance  pri_sch_nearest_distance  pri_sch_affiliation  \
# 0                  58.207761                415.607357                    1
# ...
